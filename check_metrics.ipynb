# %%
import cv2
import numpy as np
import tensorflow as tf
import keras.backend as K
import matplotlib.pyplot as plt
# %matplotlib inline

from model import Tiramisu
from datagenerator import DataGenerator
from metrics import *

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
allow_growth_session = tf.Session(config=config)
tf.keras.backend.set_session(allow_growth_session)
# Out:
# Using TensorFlow backend.

# %%
testG = DataGenerator('openeds_split', 'test', 1)

# %%
model = Tiramisu(
    input_shape=(640, 400, 3), n_classes=4, n_filters_first_conv=48,
    n_pool=4, growth_rate=6, n_layers_per_block=3, dropout_p=0.2
)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 640, 400, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 640, 400, 48) 1344        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 640, 400, 48) 192         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 640, 400, 48) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 640, 400, 6)  2598        activation_1[0][0]
# ...

# %%
model.load_weights('./models/densenet_epoch_0001.hdf5')

# %%
im, lb = testG[0]
im.shape, lb.shape
# Out:
# ((1, 640, 400, 3), (1, 640, 400, 4))

# %%
pred = model.predict(im)
out = np.array(pred[0, ...])
out = np.argmax(out, axis=-1)

# %%
pred.shape
# Out:
# (1, 640, 400, 4)

# %%
pp = K.constant(pred)
ll = K.constant(lb)

# %%
K.get_value(mean_iou(ll, pp))
# Out:
# 0.21237989

# %%
x = np.argmax(lb, axis = -1)

# %%
x.shape
# Out:
# (1, 640, 400)

# %%
def load_image(path):
	image = cv2.cvtColor(cv2.imread(path, cv2.IMREAD_COLOR), cv2.COLOR_BGR2RGB)
	return image

# %%
im_L = load_image('000000002610_L.png')

# %%
semantic_map = []
label_values = [[0,0,0], [0,239,255], [223,103,0], [0,255,24]]

for colour in label_values:
    # colour_map = np.full((label.shape[0], label.shape[1], label.shape[2]), colour, dtype=int)
    equality = np.equal(im_L, colour)
    class_map = np.all(equality, axis = -1)
    semantic_map.append(class_map)
semantic_map = np.stack(semantic_map, axis=-1)

# %%
semantic_map.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-938eb075c897> in <module>()
# ----> 1 semantic_map.shape
#
# NameError: name 'semantic_map' is not defined

# %%
plt.imshow(np.float32(semantic_map[..., 2]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a8d84296ac8d> in <module>()
# ----> 1 plt.imshow(np.float32(semantic_map[..., 2]))
#
# NameError: name 'plt' is not defined
